# %%
# reload imported modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from pathlib import Path
from typing import Dict, List, Optional
import os
import sqlite3
from src.demand_processing import process_demand

# %%
# run the demand processing
postME = True
peaks = ['am', 'pm']


project_path = f"C:/Users/IvanVelilla/Mobility Lab Limited/Projects - 1034 - Western LX Aimsun/New North Road/Model/v10"


file_path = f'{project_path}/Resources/Demand - v10.xlsx'
turn_lookup_file = f"{project_path}/Resources/turn_lookup.csv"
# output path for the processed demand
output_path = f"{project_path}/Resources/Demand/"
path_files = {
    'am': f"{project_path}/Resources/Paths/89336354_paths.csv",
    'pm': f"{project_path}/Resources/Paths/89336931_paths.csv"
}

version = "base"

# user class split
uc_splits = {
    'am': {
        'Car-T1': 78,
        'Car-T2': 19,
        'Car-T3+': 3,
        'Truck-ALL': 100
    },
    'pm': {
        'Car-T1': 70,
        'Car-T2': 25,
        'Car-T3+': 5,
        'Truck-ALL': 100
    }
}
# t2 shift test
# uc_splits = {
#     'am': {
#         'Car-T1': 73,
#         'Car-T2': 24,
#         'Car-T3+': 3,
#         'Truck-ALL': 100
#     },
#     'pm': {
#         'Car-T1': 65,
#         'Car-T2': 30,
#         'Car-T3+': 5,
#         'Truck-ALL': 100
#     }
# }


process_demand(file_path, output_path, postME, peaks, path_files, turn_lookup_file, version, uc_splits)
# Out:
# Reading data for am peak...
# Data for am peak read successfully.
# Reading data for pm peak...
# Data for pm peak read successfully.
# Processing adjustments for am peak...
# Processing adjustments for pm peak...
# Total adjustments - AM: 9265, PM: 11915
# Calculating select link adjustments for am peak...
# Select link adjustments found for am peak. Processing...
# Calculating select link adjustments for pm peak...
# Select link adjustments found for pm peak. Processing...
# Total trips by peak after adjustments:
#   peak         trips
# 0   am  57728.270749
# 1   pm  66739.861145
# {'Car-T1': 78, 'Car-T2': 19, 'Car-T3+': 3, 'Truck-ALL': 100}
# am Profiled Demand data exported to C:/Users/IvanVelilla/Mobility Lab Limited/Projects - 1034 - Western LX Aimsun/New North Road/Model/v9/Resources/Demand/postME_am_profiled_base_demand_base.csv
# {'Car-T1': 70, 'Car-T2': 25, 'Car-T3+': 5, 'Truck-ALL': 100}
# ...
